# %%
import socket
from collections import defaultdict, deque
import dpkt
import numpy as np
import pandas as pd
from pathlib import Path
import os
import struct


def inet_to_str(inet):
    try:
        return socket.inet_ntop(socket.AF_INET, inet)
    except ValueError:
        return socket.inet_ntop(socket.AF_INET6, inet)

def normalize_session(src, dst, sport, dport, proto):
    """
    Define session by (client_ip, server_ip, client_port, server_port, proto).
    Client is assumed to be the side with port != 443, server is port 443.
    """
    if dport == 443:
        client, server = (src, sport), (dst, dport)
    elif sport == 443:
        client, server = (dst, dport), (src, sport)
    else:
        # not a TLS session, skip
        return None
    return (client[0], server[0], client[1], server[1], proto)

def process_pcap_tls_manual(pcap_file, N_values=[8,16,32,64], max_packets=None):
    sessions = defaultdict(lambda: {
        "client_ts": [], "client_sizes": [],
        "server_ts": [], "server_sizes": [],
        "appdata_count": 0
    })

    with open(pcap_file, "rb") as f:
        pcap = dpkt.pcap.Reader(f)

        for i, (ts, buf) in enumerate(pcap):
            try:
                # Check if this is a Linux Cooked Capture v1 frame
                # SLL header is 16 bytes: [2 bytes packet type, 2 bytes ARPHRD, 2 bytes link layer addr len, 
                # 8 bytes link layer addr, 2 bytes protocol type]
                if len(buf) >= 16:
                    # Unpack the protocol type (last 2 bytes of SLL header)
                    protocol_type = struct.unpack('>H', buf[14:16])[0]
                    
                    if protocol_type == 0x0800:  # IPv4 protocol
                        # Skip the 16-byte SLL header and parse the IP packet
                        ip = dpkt.ip.IP(buf[16:])
                    else:
                        # Not IPv4, skip this packet
                        continue
                else:
                    # Try to parse as regular Ethernet frame
                    eth = dpkt.ethernet.Ethernet(buf)
                    if not isinstance(eth.data, dpkt.ip.IP):
                        continue
                    ip = eth.data
                
            except:
                # If parsing fails, skip this packet
                continue
            
            # Check if we have an IP packet
            if not isinstance(ip, dpkt.ip.IP):
                continue
                
            # Check if we have TCP
            l4 = ip.data
            if not isinstance(l4, dpkt.tcp.TCP):
                continue

            src = inet_to_str(ip.src)
            dst = inet_to_str(ip.dst)
            sport, dport = l4.sport, l4.dport

            #print(f"Packet {i}: {src}:{sport} -> {dst}:{dport}, TCP payload length: {len(l4.data)}")
            fid = normalize_session(src, dst, sport, dport, "TCP")
            if fid is None:
                continue

            # Skip SSL/TLS parsing entirely - use raw TCP payload
            # Calculate payload size (TCP payload length)
            tcp_payload_len = len(l4.data)
            
            if tcp_payload_len > 0:  # Only process packets with TCP payload
                if dport == 443:  # client → server
                    sessions[fid]["client_ts"].append(float(ts))
                    sessions[fid]["client_sizes"].append(tcp_payload_len)
                elif sport == 443:  # server → client
                    sessions[fid]["server_ts"].append(float(ts))
                    sessions[fid]["server_sizes"].append(tcp_payload_len)

                sessions[fid]["appdata_count"] += 1

            if max_packets and i > max_packets:
                break

    results = {N: [] for N in N_values}
    for fid, stats in sessions.items():
        combined = []
        combined += [(t, "client", s) for t, s in zip(stats["client_ts"], stats["client_sizes"])]
        combined += [(t, "server", s) for t, s in zip(stats["server_ts"], stats["server_sizes"])]
        combined.sort(key=lambda x: x[0])

        for N in N_values:
            subset = combined[:N]
            if not subset:
                continue

            client_sizes = [s for _, d, s in subset if d == "client"]
            server_sizes = [s for _, d, s in subset if d == "server"]
            client_ts = [t for t, d, _ in subset if d == "client"]
            server_ts = [t for t, d, _ in subset if d == "server"]

            client_iats = np.diff(sorted(client_ts)) if len(client_ts) > 1 else []
            server_iats = np.diff(sorted(server_ts)) if len(server_ts) > 1 else []

            # ---- New features ----
            n_client, n_server = len(client_sizes), len(server_sizes)
            client_bytes, server_bytes = np.sum(client_sizes), np.sum(server_sizes)

            pkt_fraction_client = n_client / (n_client + n_server) if (n_client + n_server) > 0 else 0.0
            bytes_fraction_client = client_bytes / (client_bytes + server_bytes) if (client_bytes + server_bytes) > 0 else 0.0

            # direction switches
            dirs = [d for _, d, _ in subset]
            # direction switches
            if len(dirs) > 1:
                dir_switches = sum(1 for i in range(1, len(dirs)) if dirs[i] != dirs[i-1])
            else:
                dir_switches = 0

            # flow duration
            flow_duration = subset[-1][0] - subset[0][0] if len(subset) > 1 else 0.0

            # time to first response
            if client_ts and server_ts:
                first_client = min(client_ts)
                first_server = min(server_ts)
                time_first_response = first_server - first_client if first_server > first_client else 0.0
            else:
                time_first_response = 0.0

            # global packet size stats
            all_sizes = [s for _, _, s in subset]
            size_min = np.min(all_sizes) if all_sizes else 0
            size_mean = np.mean(all_sizes) if all_sizes else 0.0
            size_max = np.max(all_sizes) if all_sizes else 0

            # global IAT stats (all packets regardless of dir)
            all_ts = [t for t, _, _ in subset]
            all_iats = np.diff(sorted(all_ts)) if len(all_ts) > 1 else []
            iat_min = np.min(all_iats) if len(all_iats) else 0.0
            iat_mean = np.mean(all_iats) if len(all_iats) else 0.0
            iat_max = np.max(all_iats) if len(all_iats) else 0.0
            # ----------------------

            records = {
                "session_id": fid,
                "client_ip": fid[0],
                "server_ip": fid[1],
                "client_port": fid[2],
                "server_port": fid[3],
                "protocol": fid[4],
                "N": N,

                "n_client": n_client,
                "client_bytes": int(client_bytes),
                "client_pkt_min": int(np.min(client_sizes)) if client_sizes else 0,
                "client_pkt_mean": float(np.mean(client_sizes)) if client_sizes else 0.0,
                "client_pkt_max": int(np.max(client_sizes)) if client_sizes else 0,
                "client_iat_min": float(np.min(client_iats)) if len(client_iats) else 0.0,
                "client_iat_mean": float(np.mean(client_iats)) if len(client_iats) else 0.0,
                "client_iat_max": float(np.max(client_iats)) if len(client_iats) else 0.0,

                "n_server": n_server,
                "server_bytes": int(server_bytes),
                "server_pkt_min": int(np.min(server_sizes)) if server_sizes else 0,
                "server_pkt_mean": float(np.mean(server_sizes)) if server_sizes else 0.0,
                "server_pkt_max": int(np.max(server_sizes)) if server_sizes else 0,
                "server_iat_min": float(np.min(server_iats)) if len(server_iats) else 0.0,
                "server_iat_mean": float(np.mean(server_iats)) if len(server_iats) else 0.0,
                "server_iat_max": float(np.max(server_iats)) if len(server_iats) else 0.0,

                # new flow-level ratios
                "pkt_fraction_client": pkt_fraction_client,
                "bytes_fraction_client": bytes_fraction_client,

                # new flow-level timing
                "flow_duration": flow_duration,
                "time_first_response": time_first_response,

                # new flow-level directionality
                "dir_switches": dir_switches,

                # new global stats
                "size_min": int(size_min),
                "size_mean": float(size_mean),
                "size_max": int(size_max),
                "iat_min": float(iat_min),
                "iat_mean": float(iat_mean),
                "iat_max": float(iat_max),
            }

            results[N].append(records)

    for N in results:
        results[N] = pd.DataFrame(results[N])

    return results

# %%
import pandas as pd

base_dir = Path("/home/ubuntu/DoH_DGA_training/datasets/PCAPs/DoHMalicious/iodine")
pcap_files = list(base_dir.glob("*.pcap"))

all_dfs = []

for pcap_file in pcap_files:
    if pcap_file.stat().st_size == 0:
        print(f"Skipping {pcap_file.name} (empty file)")
        continue
    
    print(f"Processing {pcap_file.name}...")
    df_dict = process_pcap_tls_manual(pcap_file, N_values=[8,16,32,64])

    # Extract label (everything before the first underscore)
    label = pcap_file.stem.split("_")[0]

    for N, df in df_dict.items():
        df["label"] = label
        df["N"] = N  # add column to track window size
        all_dfs.append(df)
        print(f"Loaded {df.shape[0]} flows with label={label}, N={N}")

# Concatenate everything into one dataframe
final_df = pd.concat(all_dfs, ignore_index=True)

# Save once
final_df.to_csv("/home/ubuntu/DoH_DGA_training/datasets/PCAPs/DoHMalicious/iodine/all_pcaps_allN.csv", index=False)
print(f"Saved aggregated dataframe with {final_df.shape[0]} flows across {final_df['label'].nunique()} labels and {final_df['N'].nunique()} N values")
# Out:
# Processing iodine_txt-64-tunnel_1111_doh7_2020-03-21T02:05:11.780252.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-32-baseline_99911_doh7_2020-03-20T04:04:27.918783.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_srv-64-baseline_1111_doh10_2020-03-22T07:03:07.291153.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_txt-64-tunnel_dnsgoogle_doh1_2020-03-18T18:55:37.032750.pcap...
# Loaded 11 flows with label=iodine, N=8
# Loaded 11 flows with label=iodine, N=16
# Loaded 11 flows with label=iodine, N=32
# Loaded 11 flows with label=iodine, N=64
# Processing iodine_null-64-tunnel_dnsadguardcom_doh1_2020-03-23T00:45:50.218681.pcap...
# Loaded 14 flows with label=iodine, N=8
# Loaded 14 flows with label=iodine, N=16
# Loaded 14 flows with label=iodine, N=32
# Loaded 14 flows with label=iodine, N=64
# Processing iodine_null-64-tunnel_dnsadguardcom_doh8_2020-03-22T21:04:51.751093.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-64-tunnel_1111_doh8_2020-03-22T19:28:23.193520.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-64-baseline_99911_doh2_2020-03-20T12:26:55.432690.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_srv-32-tunnel_1111_doh1_2020-03-21T13:06:51.489693.pcap...
# Loaded 14 flows with label=iodine, N=8
# Loaded 14 flows with label=iodine, N=16
# Loaded 14 flows with label=iodine, N=32
# Loaded 14 flows with label=iodine, N=64
# Processing iodine_srv-32-tunnel_1111_doh7_2020-03-21T11:44:11.535432.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-64-tunnel_99911_doh10_2020-03-20T06:21:34.214395.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_txt-64-tunnel_1111_doh1_2020-03-21T05:45:37.945355.pcap...
# Loaded 15 flows with label=iodine, N=8
# Loaded 15 flows with label=iodine, N=16
# Loaded 15 flows with label=iodine, N=32
# Loaded 15 flows with label=iodine, N=64
# Processing iodine_null-64-tunnel_1111_doh9_2020-03-22T22:13:53.454675.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-32-tunnel_1111_doh10_2020-03-22T14:24:43.825945.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-32-tunnel_99911_doh9_2020-03-19T23:06:49.821827.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_srv-64-tunnel_dnsadguardcom_doh2_2020-03-22T01:45:50.825128.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_srv-64-tunnel_dnsgoogle_doh5_2020-03-19T16:51:23.204908.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_txt-32-tunnel_1111_doh8_2020-03-20T21:01:27.481152.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-64-tunnel_99911_doh4_2020-03-20T10:10:44.455303.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_txt-32-tunnel_99911_doh6_2020-03-18T12:13:30.191783.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_srv-64-baseline_dnsgoogle_doh3_2020-03-19T18:44:53.274085.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-64-baseline_dnsadguardcom_doh3_2020-03-23T04:26:38.895716.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_srv-32-tunnel_dnsgoogle_doh3_2020-03-19T01:48:38.088768.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_srv-64-tunnel_dnsadguardcom_doh4_2020-03-22T03:08:46.352694.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_srv-32-tunnel_dnsgoogle_doh2_2020-03-19T05:16:53.321585.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-32-tunnel_dnsgoogle_doh1_2020-03-20T00:49:44.082349.pcap...
# Loaded 11 flows with label=iodine, N=8
# Loaded 11 flows with label=iodine, N=16
# Loaded 11 flows with label=iodine, N=32
# Loaded 11 flows with label=iodine, N=64
# Processing iodine_null-32-tunnel_dnsgoogle_doh6_2020-03-19T22:55:15.231734.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-64-baseline_dnsgoogle_doh9_2020-03-20T12:38:17.087269.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-64-tunnel_99911_doh2_2020-03-20T06:21:25.008528.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_txt-64-tunnel_dnsgoogle_doh3_2020-03-18T18:32:47.639286.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_srv-64-baseline_1111_doh1_2020-03-22T07:57:52.165438.pcap...
# Loaded 14 flows with label=iodine, N=8
# Loaded 14 flows with label=iodine, N=16
# Loaded 14 flows with label=iodine, N=32
# Loaded 14 flows with label=iodine, N=64
# Processing iodine_null-32-tunnel_1111_doh5_2020-03-22T11:10:57.295351.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_null-32-tunnel_99911_doh9_2020-03-20T01:47:38.134868.pcap...
# Loaded 1 flows with label=iodine, N=8
# Loaded 1 flows with label=iodine, N=16
# Loaded 1 flows with label=iodine, N=32
# Loaded 1 flows with label=iodine, N=64
# Processing iodine_txt-32-tunnel_dn
import pandas as pd

base_dir = Path("/home/ubuntu/DoH_DGA_training/datasets/PCAPs/DoHMalicious/dnscat2")
pcap_files = list(base_dir.glob("*.pcap"))

all_dfs = []

for pcap_file in pcap_files:
    if pcap_file.stat().st_size == 0:
        print(f"Skipping {pcap_file.name} (empty file)")
        continue
    
    print(f"Processing {pcap_file.name}...")
    df_dict = process_pcap_tls_manual(pcap_file, N_values=[8,16,32,64])

    # Extract label (everything before the first underscore)
    label = pcap_file.stem.split("_")[0]

    for N, df in df_dict.items():
        df["label"] = label
        df["N"] = N  # add column to track window size
        all_dfs.append(df)
        print(f"Loaded {df.shape[0]} flows with label={label}, N={N}")

# Concatenate everything into one dataframe
final_df = pd.concat(all_dfs, ignore_index=True)

# Save once
final_df.to_csv("/home/ubuntu/DoH_DGA_training/datasets/PCAPs/DoHMalicious/dnscat2/all_pcaps_allN.csv", index=False)
print(f"Saved aggregated dataframe with {final_df.shape[0]} flows across {final_df['label'].nunique()} labels and {final_df['N'].nunique()} N values")
# Out:
# Processing dsncat2_txt-tunnel_dnsgoogle_doh1_2020-03-23T16:04:33.473980.pcap...
# Loaded 14 flows with label=dsncat2, N=8
# Loaded 14 flows with label=dsncat2, N=16
# Loaded 14 flows with label=dsncat2, N=32
# Loaded 14 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsadguardcom_doh4_2020-03-29T07:17:49.089669.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsadguardcom_doh10_2020-03-28T21:10:33.852697.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-baseline_dnsgoogle_doh2_2020-03-26T03:13:21.391275.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_99911_doh4_2020-03-25T00:26:57.203079.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_1111_doh3_2020-03-29T07:31:33.782276.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_dnsadguardcom_doh7_2020-03-28T04:08:59.549077.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsgoogle_doh9_2020-03-24T22:49:05.749821.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_1111_doh10_2020-03-27T20:03:59.234882.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_dnsadguardcom_doh4_2020-03-27T05:00:11.100719.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_99911_doh9_2020-03-25T13:57:56.317252.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsadguardcom_doh7_2020-03-28T14:15:44.933003.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-baseline_99911_doh4_2020-03-24T20:41:31.071349.pcap...
# Loaded 0 flows with label=dsncat2, N=8
# Loaded 0 flows with label=dsncat2, N=16
# Loaded 0 flows with label=dsncat2, N=32
# Loaded 0 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_1111_doh3_2020-03-29T09:22:16.862281.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_1111_doh6_2020-03-27T21:54:53.877664.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsgoogle_doh5_2020-03-25T21:40:47.863233.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_99911_doh10_2020-03-24T15:08:26.243313.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_99911_doh5_2020-03-23T14:54:56.242584.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_dnsgoogle_doh2_2020-03-23T17:56:46.905899.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_99911_doh4_2020-03-24T06:46:12.755196.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsadguardcom_doh1_2020-03-29T08:13:06.491347.pcap...
# Loaded 14 flows with label=dsncat2, N=8
# Loaded 14 flows with label=dsncat2, N=16
# Loaded 14 flows with label=dsncat2, N=32
# Loaded 14 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_dnsadguardcom_doh9_2020-03-27T10:06:05.622477.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_dnsgoogle_doh2_2020-03-23T14:41:05.583744.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsgoogle_doh7_2020-03-25T17:27:12.936266.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsgoogle_doh7_2020-03-25T23:04:52.827336.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_dnsadguardcom_doh9_2020-03-27T23:31:58.150262.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsgoogle_doh5_2020-03-24T22:48:58.969396.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_dnsadguardcom_doh1_2020-03-27T11:29:33.577883.pcap...
# Loaded 14 flows with label=dsncat2, N=8
# Loaded 14 flows with label=dsncat2, N=16
# Loaded 14 flows with label=dsncat2, N=32
# Loaded 14 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_1111_doh9_2020-03-28T08:02:31.236075.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-baseline_1111_doh2_2020-03-28T07:07:09.802084.pcap...
# Loaded 0 flows with label=dsncat2, N=8
# Loaded 0 flows with label=dsncat2, N=16
# Loaded 0 flows with label=dsncat2, N=32
# Loaded 0 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_99911_doh10_2020-03-25T11:38:52.888236.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_1111_doh9_2020-03-28T02:59:43.661020.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsgoogle_doh4_2020-03-25T12:48:21.746070.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-baseline_dnsgoogle_doh1_2020-03-24T18:10:34.813902.pcap...
# Loaded 0 flows with label=dsncat2, N=8
# Loaded 0 flows with label=dsncat2, N=16
# Loaded 0 flows with label=dsncat2, N=32
# Loaded 0 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_dnsadguardcom_doh3_2020-03-27T05:55:44.838728.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_99911_doh1_2020-03-23T20:30:16.283967.pcap...
# Loaded 14 flows with label=dsncat2, N=8
# Loaded 14 flows with label=dsncat2, N=16
# Loaded 14 flows with label=dsncat2, N=32
# Loaded 14 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsadguardcom_doh3_2020-03-29T07:45:25.845728.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsadguardcom_doh5_2020-03-28T10:34:43.231123.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_dnsadguardcom_doh4_2020-03-28T01:50:25.227513.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_99911_doh4_2020-03-23T23:46:22.719584.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsadguardcom_doh10_2020-03-29T09:36:12.176396.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsgoogle_doh3_2020-03-25T09:33:18.498718.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_99911_doh1_2020-03-25T21:54:39.011658.pcap...
# Loaded 14 flows with label=dsncat2, N=8
# Loaded 14 flows with label=dsncat2, N=16
# Loaded 14 flows with label=dsncat2, N=32
# Loaded 14 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_99911_doh4_2020-03-25T17:41:13.174474.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_1111_doh2_2020-03-28T14:29:30.670742.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_1111_doh1_2020-03-27T01:31:50.962857.pcap...
# Loaded 14 flows with label=dsncat2, N=8
# Loaded 14 flows with label=dsncat2, N=16
# Loaded 14 flows with label=dsncat2, N=32
# Loaded 14 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_99911_doh6_2020-03-24T09:05:40.668393.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_1111_doh7_2020-03-28T22:47:15.402748.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_1111_doh6_2020-03-29T08:26:56.688399.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsgoogle_doh8_2020-03-25T14:11:51.567038.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_99911_doh9_2020-03-25T20:58:46.753299.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsadguardcom_do
pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_1111_doh9_2020-03-28T04:22:49.100101.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-tunnel_99911_doh8_2020-03-24T11:53:15.099726.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-baseline_dnsadguardcom_doh7_2020-03-29T10:58:58.345617.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_1111_doh10_2020-03-29T10:45:14.540893.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_default-tunnel_dnsgoogle_doh10_2020-03-25T12:20:42.483969.pcap...
# Loaded 1 flows with label=dsncat2, N=8
# Loaded 1 flows with label=dsncat2, N=16
# Loaded 1 flows with label=dsncat2, N=32
# Loaded 1 flows with label=dsncat2, N=64
# Processing dsncat2_txt-baseline_dnsadguardcom_doh2_2020-03-28T06:53:29.064711.pcap...
# Loaded 0 flows with label=dsncat2, N=8
# Loaded 0 flows with label=dsncat2, N=16
# Loaded 0 flows with label=dsncat2, N=32
# Loaded 0 flows with label=dsncat2, N=64
# Saved aggregated dataframe with 41192 flows across 1 labels and 4 N values

# %%
import pandas as pd

base_dir = Path("/home/ubuntu/DoH_DGA_training/datasets/PCAPs/DoHMalicious/dns2tcp")
pcap_files = list(base_dir.glob("*.pcap"))

all_dfs = []

for pcap_file in pcap_files:
    if pcap_file.stat().st_size == 0:
        print(f"Skipping {pcap_file.name} (empty file)")
        continue
    
    print(f"Processing {pcap_file.name}...")
    df_dict = process_pcap_tls_manual(pcap_file, N_values=[8,16,32,64])

    # Extract label (everything before the first underscore)
    label = pcap_file.stem.split("_")[0]

    for N, df in df_dict.items():
        df["label"] = label
        df["N"] = N  # add column to track window size
        all_dfs.append(df)
        print(f"Loaded {df.shape[0]} flows with label={label}, N={N}")

# Concatenate everything into one dataframe
final_df = pd.concat(all_dfs, ignore_index=True)

# Save once
final_df.to_csv("/home/ubuntu/DoH_DGA_training/datasets/PCAPs/DoHMalicious/dns2tcp/all_pcaps_allN.csv", index=False)
print(f"Saved aggregated dataframe with {final_df.shape[0]} flows across {final_df['label'].nunique()} labels and {final_df['N'].nunique()} N values")
# Out:
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T10:37:01.655493.pcap...
# Loaded 166 flows with label=dns2tcp, N=8
# Loaded 166 flows with label=dns2tcp, N=16
# Loaded 166 flows with label=dns2tcp, N=32
# Loaded 166 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh3_2020-03-31T11:11:09.236379.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-04-01T22:20:32.903725.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-04-01T11:27:10.596853.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh1_2020-04-01T02:02:47.956265.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T14:01:06.547778.pcap...
# Loaded 165 flows with label=dns2tcp, N=8
# Loaded 165 flows with label=dns2tcp, N=16
# Loaded 165 flows with label=dns2tcp, N=32
# Loaded 165 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh8_2020-04-01T12:00:55.356490.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh6_2020-03-31T13:27:13.098349.pcap...
# Loaded 5 flows with label=dns2tcp, N=8
# Loaded 5 flows with label=dns2tcp, N=16
# Loaded 5 flows with label=dns2tcp, N=32
# Loaded 5 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T06:05:04.211640.pcap...
# Loaded 166 flows with label=dns2tcp, N=8
# Loaded 166 flows with label=dns2tcp, N=16
# Loaded 166 flows with label=dns2tcp, N=32
# Loaded 166 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh2_2020-03-30T21:24:46.414022.pcap...
# Loaded 223 flows with label=dns2tcp, N=8
# Loaded 223 flows with label=dns2tcp, N=16
# Loaded 223 flows with label=dns2tcp, N=32
# Loaded 223 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh7_2020-04-01T04:07:03.022869.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh10_2020-03-31T00:03:18.965975.pcap...
# Loaded 149 flows with label=dns2tcp, N=8
# Loaded 149 flows with label=dns2tcp, N=16
# Loaded 149 flows with label=dns2tcp, N=32
# Loaded 149 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh1_2020-03-31T11:22:23.833171.pcap...
# Loaded 469 flows with label=dns2tcp, N=8
# Loaded 469 flows with label=dns2tcp, N=16
# Loaded 469 flows with label=dns2tcp, N=32
# Loaded 469 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh3_2020-04-01T02:25:26.436224.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh1_2020-04-01T14:49:43.154123.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh10_2020-04-01T02:59:26.139439.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh5_2020-04-01T14:15:57.032544.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh3_2020-04-01T22:09:15.721613.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh7_2020-04-01T14:15:58.470607.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T18:09:29.669597.pcap...
# Loaded 167 flows with label=dns2tcp, N=8
# Loaded 167 flows with label=dns2tcp, N=16
# Loaded 167 flows with label=dns2tcp, N=32
# Loaded 167 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh3_2020-04-01T23:28:07.512862.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh6_2020-04-01T23:50:42.854343.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh7_2020-04-01T02:48:03.381024.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh9_2020-03-31T04:34:36.641790.pcap...
# Loaded 155 flows with label=dns2tcp, N=8
# Loaded 155 flows with label=dns2tcp, N=16
# Loaded 155 flows with label=dns2tcp, N=32
# Loaded 155 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-31T21:20:41.354073.pcap...
# Loaded 62 flows with label=dns2tcp, N=8
# Loaded 62 flows with label=dns2tcp, N=16
# Loaded 62 flows with label=dns2tcp, N=32
# Loaded 62 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh9_2020-03-31T01:45:11.709436.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh9_2020-04-01T15:23:39.903805.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh8_2020-03-31T02:07:49.292835.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh7_2020-04-01T08:49:23.025860.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-31T09:40:07.127341.pcap...
# Loaded 130 flows with label=dns2tcp, N=8
# Loaded 130 flows with label=dns2tcp, N=16
# Loaded 130 flows with label=dns2tcp, N=32
# Loaded 130 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh4_2020-04-01T17:04:50.071425.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh2_2020-04-01T02:25:25.636420.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh2_2020-04-01T16:19:49.214545.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh6_2020-03-31T02:19:05.121578.pcap...
# Loaded 164 flows with label=dns2tcp, N=8
# Loaded 164 flows with label=dns2tcp, N=16
# Loaded 164 flows with label=dns2tcp, N=32
# Loaded 164 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh3_2020-03-30T22:44:13.717716.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh3_2020-04-01T04:52:11.187548.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh8_2020-04-01T11:15:58.301422.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh3_2020-04-01T05:14:41.763765.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh8_2020-03-31T09:28:52.613583.pcap...
# Loaded 160 flows with label=dns2tcp, N=8
# Loaded 160 flows with label=dns2tcp, N=16
# Loaded 160 flows with label=dns2tcp, N=32
# Loaded 160 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh10_2020-04-01T23:05:39.985384.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh10_2020-04-01T06:34:03.364994.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh5_2020-03-31T14:23:46.991318.pcap...
# Loaded 162 flows with label=dns2tcp, N=8
# Loaded 162 flows with label=dns2tcp, N=16
# Loaded 162 flows with label=dns2tcp, N=32
# Loaded 162 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh8_2020-03-30T20:26:39.801538.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh2_2020-04-01T05:14:41.173742.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh7_2020-03-31T00:37:12.176691.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh8_2020-04-01T15:46:11.009372.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-03-31T23:47:25.183023.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh9_2020-04-01T08:26:52.023155.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh8_2020-04-01T09:00:43.963216.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-04-01T04:18:18.169426.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh9_2020-03-31T11:11:15.400792.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh6_2020-03-30T21:01:56.643778.pcap...
# Loaded 107 flows with label=dns2tcp, N=8
# Loaded 107 flows with label=dns2tcp, N=16
# Loaded 107 flows with label=dns2tcp, N=32
# Loaded 107 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-30T20:26:06.150108.pcap...
# Loaded 19 flows with label=dns2tcp, N=8
# Loaded 19 flows with label=dns2tcp, N=16
# Loaded 19 flows with label=dns2tcp, N=32
# Loaded 19 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh9_2020-04-01T18:35:13.924048.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh9_2020-03-31T22:28:27.317059.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh3_2020-03-31T15:42:57.962654.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-04-01T23:28:11.389443.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh7_2020-03-30T19:51:56.712593.pcap...
# Loaded 44 flows with label=dns2tcp, N=8
# Loaded 44 flows with label=dns2tcp, N=16
# Loaded 44 flows with label=dns2tcp, N=32
# Loaded 44 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh3_2020-04-01T17:16:06.121737.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh1_2020-04-01T01:40:14.065018.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh10_2020-03-31T04:12:03.540198.pcap...
# Loaded 158 flows with label=dns2tcp, N=8
# Loaded 158 flows with label=dns2tcp, N=16
# Loaded 158 flows with label=dns2tcp, N=32
# Loaded 158 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh8_2020-03-31T10:48:29.884706.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh2_2020-03-31T06:27:46.748369.pcap...
# Loaded 165 flows with label=dns2tcp, N=8
# Loaded 165 flows with label=dns2tcp, N=16
# Loaded 165 flows with label=dns2tcp, N=32
# Loaded 165 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh7_2020-04-01T11:04:41.397974.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh2_2020-03-31T23:24:45.749652.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh5_2020-04-01T01:17:43.266392.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh2_2020-04-01T17:38:36.378938.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh8_2020-03-30T21:36:20.809500.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh7_2020-03-31T20:13:18.779769.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh9_2020-04-01T14:38:33.951833.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh5_2020-04-01T11:49:37.430566.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T14:23:45.611013.pcap...
# Loaded 161 flows with label=dns2tcp, N=8
# Loaded 161 flows with label=dns2tcp, N=16
# Loaded 161 flows with label=dns2tcp, N=32
# Loaded 161 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh4_2020-03-31T17:01:53.870580.pcap...
# Loaded 165 flows with label=dns2tcp, N=8
# Loaded 165 flows with label=dns2tcp, N=16
# Loaded 165 flows with label=dns2tcp, N=32
# Loaded 165 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh3_2020-04-01T06:33:57.833273.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh7_2020-04-01T00:21:18.221692.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh9_2020-04-01T18:01:19.804179.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-31T08:54:46.842786.pcap...
# Loaded 127 flows with label=dns2tcp, N=8
# Loaded 127 flows with label=dns2tcp, N=16
# Loaded 127 flows with label=dns2tcp, N=32
# Loaded 127 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh5_2020-03-31T12:07:48.088881.pcap...
# Loaded 165 flows with label=dns2tcp, N=8
# Loaded 165 flows with label=dns2tcp, N=16
# Loaded 165 flows with label=dns2tcp, N=32
# Loaded 165 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh1_2020-04-01T05:37:13.922856.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh3_2020-04-01T22:54:21.172305.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh3_2020-04-01T04:18:14.201161.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T01:33:44.058906.pcap...
# Loaded 151 flows with label=dns2tcp, N=8
# Loaded 151 flows with label=dns2tcp, N=16
# Loaded 151 flows with label=dns2tcp, N=32
# Loaded 151 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh7_2020-03-30T22:44:17.249654.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh8_2020-03-31T17:24:29.234105.pcap...
# Loaded 160 flows with label=dns2tcp, N=8
# Loaded 160 flows with label=dns2tcp, N=16
# Loaded 160 flows with label=dns2tcp, N=32
# Loaded 160 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh4_2020-03-30T19:40:23.036870.pcap...
# Loaded 4 flows with label=dns2tcp, N=8
# Loaded 4 flows with label=dns2tcp, N=16
# Loaded 4 flows with label=dns2tcp, N=32
# Loaded 4 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh9_2020-03-31T17:01:56.862907.pcap...
# Loaded 159 flows with label=dns2tcp, N=8
# Loaded 159 flows with label=dns2tcp, N=16
# Loaded 159 flows with label=dns2tcp, N=32
# Loaded 159 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh6_2020-03-31T03:38:12.413428.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh6_2020-03-31T03:26:52.536922.pcap...
# Loaded 165 flows with label=dns2tcp, N=8
# Loaded 165 flows with label=dns2tcp, N=16
# Loaded 165 flows with label=dns2tcp, N=32
# Loaded 165 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh5_2020-04-01T10:08:22.356393.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-04-01T21:35:25.307670.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh3_2020-04-01T13:19:30.524519.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh5_2020-04-01T15:57:22.135050.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh6_2020-03-31T01:22:30.434004.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh6_2020-03-31T03:04:18.233861.pcap...
# Loaded 161 flows with label=dns2tcp, N=8
# Loaded 161 flows with label=dns2tcp, N=16
# Loaded 161 flows with label=dns2tcp, N=32
# Loaded 161 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh1_2020-04-01T13:42:00.858762.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh10_2020-04-01T19:54:15.603731.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh3_2020-03-31T22:50:57.317587.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T09:51:33.085274.pcap...
# Loaded 169 flows with label=dns2tcp, N=8
# Loaded 169 flows with label=dns2tcp, N=16
# Loaded 169 flows with label=dns2tcp, N=32
# Loaded 169 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh9_2020-04-01T01:29:05.276961.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh1_2020-03-31T18:09:28.288548.pcap...
# Loaded 425 flows with label=dns2tcp, N=8
# Loaded 425 flows with label=dns2tcp, N=16
# Loaded 425 flows with label=dns2tcp, N=32
# Loaded 425 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh9_2020-03-31T22:05:53.682094.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh9_2020-03-31T23:36:11.415360.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh7_2020-03-31T09:51:37.443737.pcap...
# Loaded 164 flows with label=dns2tcp, N=8
# Loaded 164 flows with label=dns2tcp, N=16
# Loaded 164 flows with label=dns2tcp, N=32
# Loaded 164 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh5_2020-04-01T10:53:27.562282.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh8_2020-03-30T20:03:29.216503.pcap...
# Loaded 29 flows with label=dns2tcp, N=8
# Loaded 29 flows with label=dns2tcp, N=16
# Loaded 29 flows with label=dns2tcp, N=32
# Loaded 29 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh6_2020-03-31T05:08:33.195749.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh9_2020-04-01T09:34:32.391364.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh7_2020-03-30T23:40:39.890364.pcap...
# Loaded 161 flows with label=dns2tcp, N=8
# Loaded 161 flows with label=dns2tcp, N=16
# Loaded 161 flows with label=dns2tcp, N=32
# Loaded 161 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh4_2020-04-01T17:16:06.828891.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh2_2020-03-31T09:40:08.539836.pcap...
# Loaded 75 flows with label=dns2tcp, N=8
# Loaded 75 flows with label=dns2tcp, N=16
# Loaded 75 flows with label=dns2tcp, N=32
# Loaded 75 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh4_2020-03-31T15:09:01.375749.pcap...
# Loaded 164 flows with label=dns2tcp, N=8
# Loaded 164 flows with label=dns2tcp, N=16
# Loaded 164 flows with label=dns2tcp, N=32
# Loaded 164 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh6_2020-03-31T19:17:03.145439.pcap...
# Loaded 164 flows with label=dns2tcp, N=8
# Loaded 164 flows with label=dns2tcp, N=16
# Loaded 164 flows with label=dns2tcp, N=32
# Loaded 164 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh10_2020-03-30T22:21:44.106964.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh2_2020-03-31T20:13:15.174349.pcap...
# Loaded 129 flows with label=dns2tcp, N=8
# Loaded 129 flows with label=dns2tcp, N=16
# Loaded 129 flows with label=dns2tcp, N=32
# Loaded 129 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh7_2020-03-31T07:13:09.652235.pcap...
# Loaded 159 flows with label=dns2tcp, N=8
# Loaded 159 flows with label=dns2tcp, N=16
# Loaded 159 flows with label=dns2tcp, N=32
# Loaded 159 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh2_2020-03-31T14:23:44.715585.pcap...
# Loaded 252 flows with label=dns2tcp, N=8
# Loaded 252 flows with label=dns2tcp, N=16
# Loaded 252 flows with label=dns2tcp, N=32
# Loaded 252 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh7_2020-03-31T03:26:53.437918.pcap...
# Loaded 162 flows with label=dns2tcp, N=8
# Loaded 162 flows with label=dns2tcp, N=16
# Loaded 162 flows with label=dns2tcp, N=32
# Loaded 162 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh1_2020-03-31T05:19:45.329529.pcap...
# Loaded 352 flows with label=dns2tcp, N=8
# Loaded 352 flows with label=dns2tcp, N=16
# Loaded 352 flows with label=dns2tcp, N=32
# Loaded 352 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh4_2020-03-31T10:14:19.912890.pcap...
# Loaded 162 flows with label=dns2tcp, N=8
# Loaded 162 flows with label=dns2tcp, N=16
# Loaded 162 flows with label=dns2tcp, N=32
# Loaded 162 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh10_2020-04-01T05:37:20.998586.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh1_2020-03-31T06:05:01.617124.pcap...
# Loaded 378 flows with label=dns2tcp, N=8
# Loaded 378 flows with label=dns2tcp, N=16
# Loaded 378 flows with label=dns2tcp, N=32
# Loaded 378 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh4_2020-03-31T20:46:57.503479.pcap...
# Loaded 165 flows with label=dns2tcp, N=8
# Loaded 165 flows with label=dns2tcp, N=16
# Loaded 165 flows with label=dns2tcp, N=32
# Loaded 165 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh9_2020-04-01T15:12:22.379998.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh4_2020-04-01T04:29:36.305325.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh10_2020-03-30T19:40:39.744388.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh5_2020-03-31T09:28:50.280954.pcap...
# Loaded 167 flows with label=dns2tcp, N=8
# Loaded 167 flows with label=dns2tcp, N=16
# Loaded 167 flows with label=dns2tcp, N=32
# Loaded 167 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-31T13:04:27.600594.pcap...
# Loaded 22 flows with label=dns2tcp, N=8
# Loaded 22 flows with label=dns2tcp, N=16
# Loaded 22 flows with label=dns2tcp, N=32
# Loaded 22 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh6_2020-04-01T08:49:22.409810.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T18:54:32.600351.pcap...
# Loaded 165 flows with label=dns2tcp, N=8
# Loaded 165 flows with label=dns2tcp, N=16
# Loaded 165 flows with label=dns2tcp, N=32
# Loaded 165 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh4_2020-04-01T20:16:42.102716.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh4_2020-04-01T14:38:30.273417.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh7_2020-03-31T11:22:29.239699.pcap...
# Loaded 163 flows with label=dns2tcp, N=8
# Loaded 163 flows with label=dns2tcp, N=16
# Loaded 163 flows with label=dns2tcp, N=32
# Loaded 163 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh4_2020-04-01T03:21:55.000571.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh10_2020-04-01T10:08:25.813461.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh9_2020-04-01T14:49:48.769087.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh4_2020-03-31T16:28:05.753446.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh7_2020-03-30T20:38:21.322930.pcap...
# Loaded 86 flows with label=dns2tcp, N=8
# Loaded 86 flows with label=dns2tcp, N=16
# Loaded 86 flows with label=dns2tcp, N=32
# Loaded 86 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh1_2020-04-01T11:49:35.004989.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh7_2020-04-01T02:25:29.768970.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh1_2020-04-01T09:45:45.387252.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh10_2020-03-30T19:52:00.352354.pcap...
# Loaded 34 flows with label=dns2tcp, N=8
# Loaded 34 flows with label=dns2tcp, N=16
# Loaded 34 flows with label=dns2tcp, N=32
# Loaded 34 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh1_2020-04-01T00:21:13.960437.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh7_2020-04-01T10:19:38.919956.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh10_2020-03-31T06:27:53.535674.pcap...
# Loaded 155 flows with label=dns2tcp, N=8
# Loaded 155 flows with label=dns2tcp, N=16
# Loaded 155 flows with label=dns2tcp, N=32
# Loaded 155 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh10_2020-04-01T16:19:54.113971.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh1_2020-03-30T22:55:28.423268.pcap...
# Loaded 886 flows with label=dns2tcp, N=8
# Loaded 886 flows with label=dns2tcp, N=16
# Loaded 886 flows with label=dns2tcp, N=32
# Loaded 886 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh6_2020-04-01T17:49:56.394389.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh7_2020-04-01T14:38:32.564417.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh7_2020-03-31T02:53:04.478464.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh1_2020-04-01T18:46:27.416655.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-31T02:30:20.871673.pcap...
# Loaded 159 flows with label=dns2tcp, N=8
# Loaded 159 flows with label=dns2tcp, N=16
# Loaded 159 flows with label=dns2tcp, N=32
# Loaded 159 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh4_2020-03-31T14:57:42.537799.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh5_2020-03-31T18:54:33.691707.pcap...
# Loaded 165 flows with label=dns2tcp, N=8
# Loaded 165 flows with label=dns2tcp, N=16
# Loaded 165 flows with label=dns2tcp, N=32
# Loaded 165 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh10_2020-04-01T02:36:51.346969.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh7_2020-04-01T03:33:12.759331.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-04-01T00:09:59.706471.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh4_2020-03-30T23:29:23.115679.pcap...
# Loaded 2 flows with label=dns2tcp, N=8
# Loaded 2 flows with label=dns2tcp, N=16
# Loaded 2 flows with label=dns2tcp, N=32
# Loaded 2 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh6_2020-04-01T21:57:57.371269.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh6_2020-03-31T21:09:27.980171.pcap...
# Loaded 163 flows with label=dns2tcp, N=8
# Loaded 163 flows with label=dns2tcp, N=16
# Loaded 163 flows with label=dns2tcp, N=32
# Loaded 163 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh4_2020-04-01T22:20:30.034026.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh10_2020-03-31T06:39:16.459873.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T21:31:54.974406.pcap...
# Loaded 163 flows with label=dns2tcp, N=8
# Loaded 163 flows with label=dns2tcp, N=16
# Loaded 163 flows with label=dns2tcp, N=32
# Loaded 163 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh6_2020-03-30T21:36:16.612625.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh4_2020-04-01T05:37:16.351787.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh5_2020-03-31T11:11:11.654461.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh8_2020-04-01T16:08:41.336914.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh7_2020-04-01T08:15:36.972939.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh4_2020-03-31T02:53:01.817546.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh5_2020-04-01T13:53:22.714749.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh7_2020-04-01T02:02:53.596440.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh4_2020-03-31T22:28:23.644554.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh7_2020-03-30T20:26:32.524914.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh4_2020-04-01T16:19:50.423625.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh3_2020-04-01T05:48:40.764715.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-31T15:20:20.127719.pcap...
# Loaded 64 flows with label=dns2tcp, N=8
# Loaded 64 flows with label=dns2tcp, N=16
# Loaded 64 flows with label=dns2tcp, N=32
# Loaded 64 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh5_2020-04-01T18:46:30.146669.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh8_2020-03-30T21:59:04.146881.pcap...
# Loaded 7 flows with label=dns2tcp, N=8
# Loaded 7 flows with label=dns2tcp, N=16
# Loaded 7 flows with label=dns2tcp, N=32
# Loaded 7 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh4_2020-03-31T07:13:06.787915.pcap...
# Loaded 165 flows with label=dns2tcp, N=8
# Loaded 165 flows with label=dns2tcp, N=16
# Loaded 165 flows with label=dns2tcp, N=32
# Loaded 165 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh9_2020-04-01T02:36:50.672258.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh1_2020-03-31T07:13:02.880575.pcap...
# Loaded 462 flows with label=dns2tcp, N=8
# Loaded 462 flows with label=dns2tcp, N=16
# Loaded 462 flows with label=dns2tcp, N=32
# Loaded 462 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh10_2020-03-31T14:57:49.218403.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh10_2020-03-31T12:30:34.308477.pcap...
# Loaded 156 flows with label=dns2tcp, N=8
# Loaded 156 flows with label=dns2tcp, N=16
# Loaded 156 flows with label=dns2tcp, N=32
# Loaded 156 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh5_2020-03-31T13:04:33.001765.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh2_2020-03-31T20:35:44.098165.pcap...
# Loaded 28 flows with label=dns2tcp, N=8
# Loaded 28 flows with label=dns2tcp, N=16
# Loaded 28 flows with label=dns2tcp, N=32
# Loaded 28 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh9_2020-04-01T05:25:59.622706.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh6_2020-04-01T20:16:43.197838.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh3_2020-03-31T21:20:43.029822.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh3_2020-04-01T05:25:55.519439.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh2_2020-04-01T09:45:46.182119.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh2_2020-03-31T02:30:22.366168.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh7_2020-04-01T06:56:37.084531.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh7_2020-04-01T12:34:34.749812.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh1_2020-03-30T20:14:43.990740.pcap...
# Loaded 42 flows with label=dns2tcp, N=8
# Loaded 42 flows with label=dns2tcp, N=16
# Loaded 42 flows with label=dns2tcp, N=32
# Loaded 42 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh2_2020-03-30T21:58:57.689314.pcap...
# Loaded 55 flows with label=dns2tcp, N=8
# Loaded 55 flows with label=dns2tcp, N=16
# Loaded 55 flows with label=dns2tcp, N=32
# Loaded 55 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh5_2020-04-01T05:37:17.040861.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh9_2020-04-01T09:57:04.566217.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh10_2020-04-01T01:40:21.362335.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh4_2020-03-31T22:17:04.401090.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh1_2020-04-01T13:53:20.193599.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh3_2020-03-31T08:32:13.070592.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh1_2020-04-01T05:03:21.761629.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh5_2020-04-01T16:19:50.947311.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-31T06:16:27.794411.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# ...
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh3_2020-04-01T07:19:09.179603.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-31T00:37:06.632933.pcap...
# Loaded 224 flows with label=dns2tcp, N=8
# Loaded 224 flows with label=dns2tcp, N=16
# Loaded 224 flows with label=dns2tcp, N=32
# Loaded 224 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh7_2020-03-31T17:24:28.548213.pcap...
# Loaded 162 flows with label=dns2tcp, N=8
# Loaded 162 flows with label=dns2tcp, N=16
# Loaded 162 flows with label=dns2tcp, N=32
# Loaded 162 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh5_2020-03-31T02:41:43.375022.pcap...
# Loaded 164 flows with label=dns2tcp, N=8
# Loaded 164 flows with label=dns2tcp, N=16
# Loaded 164 flows with label=dns2tcp, N=32
# Loaded 164 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh4_2020-04-01T07:53:04.013797.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh10_2020-03-30T19:17:40.603293.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh2_2020-03-31T05:31:05.975204.pcap...
# Loaded 26 flows with label=dns2tcp, N=8
# Loaded 26 flows with label=dns2tcp, N=16
# Loaded 26 flows with label=dns2tcp, N=32
# Loaded 26 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh2_2020-04-01T06:45:17.196905.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh10_2020-03-31T12:53:14.723810.pcap...
# Loaded 156 flows with label=dns2tcp, N=8
# Loaded 156 flows with label=dns2tcp, N=16
# Loaded 156 flows with label=dns2tcp, N=32
# Loaded 156 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh3_2020-03-31T07:13:05.868988.pcap...
# Loaded 166 flows with label=dns2tcp, N=8
# Loaded 166 flows with label=dns2tcp, N=16
# Loaded 166 flows with label=dns2tcp, N=32
# Loaded 166 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh10_2020-04-01T21:12:56.493554.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh2_2020-03-31T12:30:27.415865.pcap...
# Loaded 229 flows with label=dns2tcp, N=8
# Loaded 229 flows with label=dns2tcp, N=16
# Loaded 229 flows with label=dns2tcp, N=32
# Loaded 229 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-04-01T00:55:09.945188.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh9_2020-03-30T21:59:05.322719.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh9_2020-03-31T07:35:48.097102.pcap...
# Loaded 158 flows with label=dns2tcp, N=8
# Loaded 158 flows with label=dns2tcp, N=16
# Loaded 158 flows with label=dns2tcp, N=32
# Loaded 158 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh3_2020-03-31T07:01:47.675429.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh7_2020-03-30T19:17:32.524848.pcap...
# Loaded 2 flows with label=dns2tcp, N=8
# Loaded 2 flows with label=dns2tcp, N=16
# Loaded 2 flows with label=dns2tcp, N=32
# Loaded 2 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh8_2020-03-31T11:22:30.033636.pcap...
# Loaded 160 flows with label=dns2tcp, N=8
# Loaded 160 flows with label=dns2tcp, N=16
# Loaded 160 flows with label=dns2tcp, N=32
# Loaded 160 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh6_2020-03-31T13:15:51.874625.pcap...
# Loaded 158 flows with label=dns2tcp, N=8
# Loaded 158 flows with label=dns2tcp, N=16
# Loaded 158 flows with label=dns2tcp, N=32
# Loaded 158 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh5_2020-03-31T23:24:48.182207.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh6_2020-04-01T22:09:17.710526.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh6_2020-04-01T02:36:48.183786.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh1_2020-03-31T13:15:47.482289.pcap...
# Loaded 421 flows with label=dns2tcp, N=8
# Loaded 421 flows with label=dns2tcp, N=16
# Loaded 421 flows with label=dns2tcp, N=32
# Loaded 421 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh1_2020-04-01T18:57:42.417037.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh10_2020-04-01T10:42:13.229355.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh1_2020-04-01T10:30:53.109990.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh1_2020-04-01T06:45:16.197598.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh7_2020-04-01T19:09:07.427395.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh10_2020-04-01T16:53:41.100923.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh6_2020-03-30T22:10:19.166754.pcap...
# Loaded 194 flows with label=dns2tcp, N=8
# Loaded 194 flows with label=dns2tcp, N=16
# Loaded 194 flows with label=dns2tcp, N=32
# Loaded 194 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh4_2020-03-31T18:09:30.285838.pcap...
# Loaded 166 flows with label=dns2tcp, N=8
# Loaded 166 flows with label=dns2tcp, N=16
# Loaded 166 flows with label=dns2tcp, N=32
# Loaded 166 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh6_2020-03-30T22:55:33.619458.pcap...
# Loaded 159 flows with label=dns2tcp, N=8
# Loaded 159 flows with label=dns2tcp, N=16
# Loaded 159 flows with label=dns2tcp, N=32
# Loaded 159 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh1_2020-03-31T01:11:02.621986.pcap...
# Loaded 246 flows with label=dns2tcp, N=8
# Loaded 246 flows with label=dns2tcp, N=16
# Loaded 246 flows with label=dns2tcp, N=32
# Loaded 246 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh6_2020-03-31T07:01:50.660119.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh6_2020-04-01T11:49:38.096360.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh8_2020-03-31T20:24:31.131069.pcap...
# Loaded 160 flows with label=dns2tcp, N=8
# Loaded 160 flows with label=dns2tcp, N=16
# Loaded 160 flows with label=dns2tcp, N=32
# Loaded 160 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh9_2020-03-31T04:45:58.551790.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh2_2020-04-01T13:30:46.871744.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh8_2020-03-30T20:50:23.270727.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh7_2020-04-01T21:46:42.547756.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh1_2020-04-01T04:06:58.909493.pcap...
# Loaded 11 flows with label=dns2tcp, N=8
# Loaded 11 flows with label=dns2tcp, N=16
# Loaded 11 flows with label=dns2tcp, N=32
# Loaded 11 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh6_2020-03-31T20:13:18.054276.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh2_2020-03-31T18:54:31.906255.pcap...
# Loaded 215 flows with label=dns2tcp, N=8
# Loaded 215 flows with label=dns2tcp, N=16
# Loaded 215 flows with label=dns2tcp, N=32
# Loaded 215 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh7_2020-03-31T16:28:07.843323.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh10_2020-04-01T10:30:59.945730.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-04-01T10:42:11.794427.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh5_2020-04-01T23:39:28.079226.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh9_2020-03-31T18:20:51.965813.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh4_2020-03-31T03:26:51.255859.pcap...
# Loaded 166 flows with label=dns2tcp, N=8
# Loaded 166 flows with label=dns2tcp, N=16
# Loaded 166 flows with label=dns2tcp, N=32
# Loaded 166 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh5_2020-04-01T15:12:18.561079.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh6_2020-04-01T19:54:13.478153.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh4_2020-04-01T19:20:18.250612.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh4_2020-03-31T11:22:27.098695.pcap...
# Loaded 167 flows with label=dns2tcp, N=8
# Loaded 167 flows with label=dns2tcp, N=16
# Loaded 167 flows with label=dns2tcp, N=32
# Loaded 167 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh7_2020-03-31T15:43:01.366152.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh6_2020-03-30T21:59:02.054842.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh2_2020-04-01T23:05:34.388632.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh8_2020-03-31T00:25:52.100308.pcap...
# Loaded 160 flows with label=dns2tcp, N=8
# Loaded 160 flows with label=dns2tcp, N=16
# Loaded 160 flows with label=dns2tcp, N=32
# Loaded 160 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh5_2020-04-01T14:27:10.478888.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh6_2020-04-01T19:20:19.554663.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh10_2020-04-01T12:12:08.383993.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh8_2020-04-01T18:46:32.833473.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh9_2020-03-31T23:47:26.009991.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh1_2020-03-31T07:24:25.510304.pcap...
# Loaded 64 flows with label=dns2tcp, N=8
# Loaded 64 flows with label=dns2tcp, N=16
# Loaded 64 flows with label=dns2tcp, N=32
# Loaded 64 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsadguardcom_doh5_2020-04-01T00:21:16.735989.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_dnsgoogle_doh7_2020-03-31T19:50:49.857875.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_1111_doh8_2020-04-01T13:19:33.574108.pcap...
# Loaded 1 flows with label=dns2tcp, N=8
# Loaded 1 flows with label=dns2tcp, N=16
# Loaded 1 flows with label=dns2tcp, N=32
# Loaded 1 flows with label=dns2tcp, N=64
# Processing dns2tcp_tunnel_99911_doh9_2020-03-31T17:24:29.830051.pcap...
# Loaded 162 flows with label=dns2tcp, N=8
# Loaded 162 flows with label=dns2tcp, N=16
# Loaded 162 flows with label=dns2tcp, N=32
# Loaded 162 flows with label=dns2tcp, N=64
# Saved aggregated dataframe with 616568 flows across 1 labels and 4 N values
